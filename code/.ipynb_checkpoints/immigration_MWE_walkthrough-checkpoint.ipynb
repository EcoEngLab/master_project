# %% [markdown]
# # MWE walkthrough of a community assembly simulation with a single fixed immigration rate

# %% [markdown]
# **Objective: To inspire others on how to develop immigration/coalesence simulations.**
# ## Context
# Microbial communities play a crucial role in all ecosystems, yet understanding how to effectively manipulate them remains a key challenge. The area of synthetic microbial ecology is attracting growing attention as computational power advances, enabling researchers to simulate and manipulate highly complex ecosystems. I used computational simulations to investigate the effects of immigration on the energy use efficiency (EUE) of microbial communities. The EUE of simulated microbial communities remains unexplored. I studied the niche width of the microbial strains, species diversity, and how immigration rates could be engineered in microbial communities. The results show that EUE increases with immigration rates up to a certain point, after which it saturates but does not collapse as the immigration rate increases and time continues. Importantly, whether the microbial strains were specialists or generalists did not significantly impact EUE. This suggests that all communities will achieve an optimal EUE through varied structures, indicating the presence of multiple stable states rather than a single one. A clear positive relationship between EUE and species diversity was observed, although beyond a certain threshold, further increases in diversity did not affect EUE. In summary, using a top-down approach to community engineering, I have shown that the EUE of microbial communities can be manipulated using immigration regimes. The EUE of a microbial community can be optimised by increasing immigration regardless of niche width, although differing niche width compositions within the community may offer insight into the varied structures in obtaining optimal EUE. Future work should focus on replicating these results with different mathematical models and developing practical methods to test this theory in live microorganism communities.

# %% [markdown]
# ## The model
#  The change in metabolite $\beta$ concentration over time can be expressed as
# $$
# \frac{dC_{\beta}}{dt} = \kappa \delta_{\beta, 1} - \rho C_{\beta} + \sum_{i=1}^{B} \left( p_{i, \beta} (\mathbb{C}) - c_{i, \beta} (\mathbb{C}) \right) N_i
# $$

# %% [markdown]
# where $\kappa$ is the substrate supply rate, $\delta_{\beta, 1}$ is Kronecker's delta, $\rho$ is metabolite dilution rate, $B$ is the number of species in the community, $p_{i, \beta}$ is the per cell rate that the \textit{i}\textsuperscript{th} species produces metabolite $\beta$, $\mathbb{C}$ is a vector of all metabolite concentrations, $c_{i, \beta}$ is the per cell rate that the $i^{th}$ species consumes metabolite $\beta$.
#
# The change in consumer population abundance over time is given by

# %% [markdown]
# $$
# \frac{dN_i}{dt} = \left( \lambda_i(a_i, \phi_{R,i}) - d_i \right) N_i
# $$

# %% [markdown]
# where $\lambda_i$ is the growth rate, $a_i$ is the internal energy (ATP) concentration, $\phi_{R,i}$ is the ribosome fraction and $d_i$ is the rate of biomass loss.
#
# The change in ribosome fraction over time is expressed as

# %% [markdown]
# $$
# \frac{d\phi_{R,i}}{dt} = \frac{1}{\tau_g} \left( \phi^*_{R}(a_i) - \phi_{R,i} \right)
# $$

# %% [markdown]
# where $\tau_g$ is the characteristic time scale for growth and $\phi^*_{R}$ is the ideal ribosome fraction.

# %% [markdown]
# ## Simulation workflow
# ![alt text](<code architecture.png>)
# #### 1. Load in the dev package

# %%
using Pkg
Pkg.develop(path=raw"C:\Users\zyser\Documents\EcosystemAssembly\TradeOff")
using TradeOff
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\zyser\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\zyser\.julia\environments\v1.11\Manifest.toml`

# %% [markdown]
# #### 2. Make the pool of different species that the microbes will be selected from.
# The niche widths of these microbes vary from 1 to 5 reactions.

# %%
include("TradeOff/src/immigration/gen_pool.jl")
include("TradeOff/src/immigration/simulation_functions.jl")
import TradeOff.fix_reactions, TradeOff.new_mic, TradeOff.initialise
import Random

Nt = 5000 # Number of microbes in pool
M = 25 # Number of metabolites in pool
Rs = collect(1:5) # Number of reactions in each microbe
d = 6e-5 # Biomass loss rate
μrange = 1.5e7 * (M / 25) #  free energy difference between the initial metabolite, and the lowest free energy metabolite
mratio = 1e-2 /3   # Substrate ratio for equilibrium

# First generate random unique identifier for this pool
PID = "exampleP"
# Print out that this is happening
println("Generating random pool with identifier: $(PID)")

# Cell mass is taken from Bremer H, Dennis P (1996) Modulation of chemical
# composition and other parameters of the cell by growth rate (Book chapter).
MC = 10^8
# Elongation rate also taken from Bremer (1996), convert from minutes to seconds
γm = 1260.0 / 60.0
# ribosome mass taken from Keseler IM, et al. (2011)
nr = 7459
# Standard protein mass averaged from Brandt F, et al. (2009)
ns = 300
# The proportion of ribosomes bound is taken from Underwood et al to be 70%
Pb = 0.7
# Number of doublings required to dilute to 1%
fd = log(100) / log(2)
# Housekeeping fraction is taken from Scott et al. 2010
ϕH = 0.45
# The number of ATP per translation step, including the cost of amino acid synthesis
# This figure is taken from Lynch and Marinov 2015
χl = 29.0
# This is a slightly arbitrary choice for Kγ
Kγ = 5e8
# Set minimum KΩ value
KΩ = 2.5e8

# Use formula to calculate how many reactions are implied
if M < 4
    O = floor(Int64, M * (M - 1) / 2)
else
    O = 4 * M - 10
end

# Assume that temperature T is constant at 20°C
T = 293.15
# Generate fixed set of reactions
RP, ΔG = fix_reactions(O, M, μrange, T)

# Preallocate vector of reactions
reacs = Array{Reaction, 1}(undef, O)
for i in 1:O
    reacs[i] = make_Reaction(i, RP[i, 1], RP[i, 2], ΔG[i])
end

# Assume that half saturation occurs at a quarter κ/δ
KS = (1 / 4) * 5.5e-3
# Arbitrary number that seems to give decent survival
kc = 10.0
# The reversibility factor remains the same as previously
kr = 10.0
# Preallocate vector of microbes
mics = Array{Microbe, 1}(undef, Nt)
# Then construct microbes
for i in 1:Nt
    # For each microbe generate random set of reactions
    R, Reacs = choose_reactions(O, Rs)
    # Now preallocate protein masses
    n = zeros(Int64, 2 + R)
    # First element is ribosome mass
    n[1] = nr
    # Second is housekeeping
    n[2] = ns
    # Determine the others based on reactions
    for j in 1:R
        n[2 + j] = ns * (reacs[Reacs[j]].Prd - reacs[Reacs[j]].Rct)
    end
    # Roller et al suggest a factor of 10 variation in max growth rate
    # So varies between 0.1 and 1.0
    ω = 0.1 + 0.9 * rand()
    # Make vectors of the (fixed) kinetic parameters
    kcs, KSs, krs = kin_rand(kc, KS, kr, R)
    # Reactions given random proportional weightings, done this in the simplest way possible
    ϕP = rand(R)
    ϕP = ϕP / sum(ϕP)
    # Find corresponding η's for these reactions
    η = choose_η_mix(reacs, Reacs, T, mratio)
    # Can finally generate microbe
    mics[i] = make_Microbe(MC,
        γm,
        Kγ,
        χl,
        Pb,
        d,
        ϕH,
        KΩ,
        fd,
        ω,
        R,
        Reacs,
        η,
        kcs,
        KSs,
        krs,
        n,
        ϕP,
        i,
        PID)
end
# Out:
# Generating random pool with identifier: exampleP
# WARNING: could not import TradeOff.fix_reactions into Main
# WARNING: could not import TradeOff.new_mic into Main

# %% [markdown]
# #### 3. Simulate assembly

# %%
import TradeOff.full_dynamics!
function demo_full_simulate(ps::TOParameters, 
    pop::Float64,
    conc::Float64,
    as::Float64,
    ϕs::Float64,
    mpl::Array{Microbe, 1},
    Ni::Int64,
    mT::Float64,
    total_time::Float64, # Total simulation time
    num_immigrations::Int64, # Number of immigration events
    num_immigrants::Int64) # Number of immigrants per event

    # Make container to store microbial data
    micd = Array{MicData}(undef, Ni)

    # Make container to store trajectory data
    traj = Array{Array{Float64, 2}}(undef, num_immigrations + 1)

    # Set a value for the maximum number of strains that can be simulated
    max_N = 300

    # Preallocate memory
    rate = Array{Float64, 2}(undef, max_N, ps.O)

    # Now substitute preallocated memory in
    dyns!(dx, x, ms, t) = full_dynamics!(dx, x, ms, ps, rate, t)

    # Preallocate initial vector of microbes
    ms = Array{Microbe, 1}(undef, Ni)

    # Bool to store if full vector of microbes has been found
    full = false
    i = 1
    # Randomly choose them from the pool
    while full == false
        r = rand(1:length(mpl))

        # Check that strain hasn't already been added
        if mpl[r] ∉ ms[1:(i - 1)]
            # And if not add it
            ms[i] = mpl[r]
            # Increment counter
            i += 1
        end

        # End while loop when all the microbes have been filled
        if i == length(ms) + 1
            full = true
        end
    end

    # Store generated microbes as MicData
    for i in 1:Ni
        micd[i] = make_MicData(ms[i].ID, ms[i].PID, 0.0, NaN)
    end

    # Initial number of surviving strains is equal to 1
    Ns = Ni

    # Make initial values
    pops = pop * ones(length(ms))
    concs = conc * ones(ps.M)
    ass = as * ones(length(ms))
    ϕss = ϕs * ones(length(ms))
    x0 = [pops; concs; ass; ϕss]

    # Preallocate immigration times
    its = range(0, stop=total_time, length=num_immigrations+1)[2:end]  # Evenly spread immigration times
    
    # Define initial step
    tspan = (0, its[1])

    # Then setup and solve the initial problem
    prob = ODEProblem(dyns!, x0, tspan, ms)
    sol = DifferentialEquations.solve(prob)

    # Make containers to store dynamics
    T = sol.t
    C = copy(sol')

    # Save this C for output
    traj[1] = C[:, :]

    # Find indices of surviving strains
    inds = sol'[end, 1:Ni] .> 1e-5

    # Make vector to store indices to delete
    dls = []

    # Find any extinctions
    for i in 1:Ni
        if inds[i] == false
            # Mark extinction time in the microbe data
            micd[i] = make_MicData(micd[i].MID, micd[i].PID, micd[i].ImT, its[1])
            # Mark species for deletion
            dls = cat(dls, i, dims = 1)
            # Set extinct species values as NaN in the output data
            C[end, i] = NaN
            C[end, ps.M + Ni + i] = NaN
            C[end, ps.M + 2 * Ni + i] = NaN
            # Reduce number of surviving strains counter by 1
            Ns -= 1
        end
    end

    # Delete extinct species
    ms = deleteat!(ms, dls)

    # Now loop over for every immigration attempt
    for i in 1:num_immigrations
        # println("Immigration attempt $i initiated")
        #     flush(stdout)
        if i % 10 == 0
            println("Immigration attempt $i initiated")
            flush(stdout)
        end

        # Use fixed number of immigrants
        nI = num_immigrants

        # Make new vector to store microbes
        mst = Array{Microbe, 1}(undef, nI)

        # Make container to store microbial data
        micdt = Array{MicData}(undef, nI)

        # Set up while loop to check microbes
        j = 1
        full = false

        # Randomly choose them from the pool
        while full == false
            r = rand(1:length(mpl))

            # Check that strain hasn't already been added
            if mpl[r] ∉ ms && mpl[r] ∉ mst[1:(j - 1)]

            # And if not add it
            mst[j] = mpl[r]
            
            # Increment counter
            j += 1
        end
        # End while loop when all the microbes have been filled
        if j == length(mst) + 1
            full = true
        end
    end

    # Add microbes to the existing vector
    ms = cat(ms, mst, dims = 1)

    # Find new MicData values
    for j in 1:nI
        micdt[j] = make_MicData(mst[j].ID, mst[j].PID, its[i], NaN)
    end

    # Add this new data to the old
    micd = cat(micd, micdt, dims = 1)

    # Find time to next immigration, if not at the last step
    if i != num_immigrations
        # Use previous immigration time to define the time step
        tspan = (its[i], its[i + 1])
    else
        # At last step just integrate for five times the average time, so that dynamics settle
        tf = total_time + 1 * mT
        # Use previous immigration time to define the time span
        tspan = (its[i], tf)
    end

    # Find all indices of still relevant initial conditions in C
    in_cons = findall(!isnan, C[end, :])

    # Then find initial conditions directly from C
    pops_old = C[end, in_cons[1:Ns]]
    concs = C[end, in_cons[(Ns + 1):(Ns + ps.M)]]
    as_old = C[end, in_cons[(Ns + ps.M + 1):(2 * Ns + ps.M)]]
    ϕs_old = C[end, in_cons[(2 * Ns + ps.M + 1):(3 * Ns + ps.M)]]

    # Find indices of concentrations below threshold and overwrite
    nCids = findall(x -> x < 1e-15, concs)

    # Then set all these to zero
    concs[nCids] .= 1e-15

    # Make new vectors incorporating old and new microbes
    pops = cat(pops_old, pop * ones(length(mst)), dims = 1)
    ass = cat(as_old, as * ones(length(mst)), dims = 1)
    ϕss = cat(ϕs_old, ϕs * ones(length(mst)), dims = 1)

    # Collect all of this together in a vector of initial conditions
    x0 = [pops; concs; ass; ϕss]

    # Now setup and solve the problem with the new strains
    prob = ODEProblem(dyns!, x0, tspan, ms)
    sol = DifferentialEquations.solve(prob)

    # Update the number of survivors, as new strains have been added
    Ns += nI

    # Store new dynamics in a temporary form
    Tt = sol.t
    C = copy(sol')

    # Save new dynamics for output
    traj[i + 1] = C

    # Add to full vector of times
    T = cat(T, Tt[2:end], dims = 1)

    # Now find indices of recently extinct strains
    inds = (C[end, 1:Ns] .<= 1e-5)

    # Make vector to store indices to delete
    dls = []

    # Find indices of all strains that still survive in micd
    svs = findall(isnan, (micd .↦ :ExT))

    # Find any extinctions
    for j in 1:Ns
        if inds[j] == true
            # Find index of the newly extinct strain
            ex = svs[j]
            # The essential problem is converting j into the true index
            # Mark extinction time in the microbe data
            micd[ex] = make_MicData(micd[ex].MID, micd[ex].PID, micd[ex].ImT, tspan[2])
            # Find indices of species with ID's matching the one being made extinct
            sinds = findall(x -> x == micd[ex].MID, ms .↦ :ID)
            # Check if there's multiple
            if length(sinds) > 1
                # If there is compare pool ids
                pind = findfirst(x -> x == micd[ex].PID, ms[sinds] .↦ :PID)
                sind = sinds[pind]
            else
                sind = sinds[1]
            end
            # Mark species for deletion
            dls = cat(dls, sind, dims = 1)
            # Set extinct species values as NaN in the output data
            C[end, j] = NaN
            C[end, ps.M + Ns + j] = NaN
            C[end, ps.M + 2 * Ns + j] = NaN
        end
    end
    
    # Reduce number of surviving strains by the number of extinctions
    Ns -= sum(inds)
    # Delete extinct species
    ms = deleteat!(ms, dls)
    end
    return (traj, T, micd, its)
end
# Out:
# demo_full_simulate (generic function with 1 method)

# %%
using JLD2

rps = 1
sim_type = 1
immigration_rate = 80
num_immigrants = 1
num_immigrations = 80
rl = 1
ru = 5

# Define duration of assembly
total_time = 3.15e7 # 1 year

# Starting run assumed to be 1
Rs = 1

# Now read in hard coded simulation parameters
Np = 1 # Number of pools
Nt = 5000 # Number of strains
M = 25 # Number of metabolites
d = 6e-5 # Biomass loss rate
μrange = 1.5e7 * (M / 25)

# Use formula to find number of reactions depending on number of metabolites
if M < 4
    O = floor(Int64, M * (M - 1) / 2)
else
    O = 4 * M - 10
end

# Hardcoded parameters:
ϕR0 = 0.128 # Initial ribosome fraction is taken from ATP fits I did a while ago
# Fairly arbitrary initial conditions
pop = 1000.0
conc = 1e-15
as = 1e5
ϕs = ϕR0
# Starting with 1 strain for now
Ni = 1

# Time between immigration events
mT = 3.15e7 / immigration_rate

# Make parameter set
ps = initialise(M, O, μrange)

mpl = mics

traj, T, micd, its = demo_full_simulate(ps, pop, conc, as, ϕs, mpl, Ni, mT, total_time, num_immigrations, num_immigrants)
# Out:
# Immigration attempt 10 initiated
# Immigration attempt 20 initiated
# Immigration attempt 30 initiated
# Immigration attempt 40 initiated
# Immigration attempt 50 initiated
# Immigration attempt 60 initiated
# Immigration attempt 70 initiated
# Immigration attempt 80 initiated
# ...

# %%
its_vector = collect(its)

# Use to construct full trajectory C
GC.gc()
C = imm_merge_data(ps, traj, T, micd, its_vector)

# Save total number of strains
total_species = length(micd)

# Preallocate containers to store number of survivors with time
surviving_species = Array{Int64, 1}(undef, length(T))

# Loop over all time points
for j in 1:length(T)
    # Find indices of surviving strains
    inds = findall(x -> x > 1e-5, C[j, 1:total_species])
    # Save number of surviving strains at each time point
    surviving_species[j] = length(inds)
end

# %%
using Plots
plot(T, surviving_species, label="Surviving species", xlabel="Time (s)", ylabel="Number of species", title="Number of surviving species over time")

# %% [markdown]
# # HPC simulation of parallel assembly simulations

# %%
#!/bin/bash
#SBATCH --time=0-10:00:00
#SBATCH --ntasks=1
#SBATCH --cpus-per-task=1
#SBATCH --mem=70G
#SBATCH --partition=large_336
#SBATCH --output=job_%A_%a.log
#SBATCH --array=0-6

# Array of immigration rates
rates=(10 20 40 80 160 320 640)

# Retrieve the rate based on the array task ID
rate=${rates[$SLURM_ARRAY_TASK_ID]}

# Determine the task type based on a passed argument
task_type=$1

if [[ "$task_type" == "simulation" ]]; then
    julia ./src/immigration/assemble.jl 20 1 $rate 1 1 5
elif [[ "$task_type" == "analysis" ]]; then
    julia ./src/immigration/analysis.jl 20 1 $rate 1 1 5
elif [[ "$task_type" == "averaging" ]]; then
    julia ./src/immigration/averages.jl 20 1 $rate 1 1 5
else
    echo "Invalid task type: $task_type"
    exit 1
fi

#arguments: repeats, simulation type, immigration rate, number of immigrants,  no. reactions lower bound, no. reactions upper bound
# Out:
# ParseError:
#
# # Error @ c:\Users\zyser\Documents\EcosystemAssembly\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X24sZmlsZQ==.jl:11:11
#
# # Array of immigration rates
#
# rates=(10 20 40 80 160 320 640)
#
# #         └──────────────────┘ ── Expected `)`
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\zyser\Documents\EcosystemAssembly\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X24sZmlsZQ==.jl:11

# %%
sbatch --array=0-6 src/immigration/array_parallel.sh simulation
# Out:
# ParseError:
#
# # Error @ c:\Users\zyser\Documents\EcosystemAssembly\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X25sZmlsZQ==.jl:1:8
#
# sbatch --array=0-6 src/immigration/array_parallel.sh simulation
#
# #      └┘ ── invalid operator
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\zyser\Documents\EcosystemAssembly\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X25sZmlsZQ==.jl:1
